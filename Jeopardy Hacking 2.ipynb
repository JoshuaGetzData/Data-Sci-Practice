# %% [markdown]
# # Jeopardy Hacking
#
# Here we will practice chi square computations using a data set of jeopardy questions. We want to see if any questions or terms are more likely to reoccur in a new question so we can be sure to gain information on the matter.

# %%
import pandas as pd

jeopardy = pd.read_csv('jeopardy.csv')

jeopardy
# Out:
#        Show Number    Air Date             Round  \
# 0             4680  2004-12-31         Jeopardy!
# 1             4680  2004-12-31         Jeopardy!
# 2             4680  2004-12-31         Jeopardy!
# 3             4680  2004-12-31         Jeopardy!
# 4             4680  2004-12-31         Jeopardy!
# 5             4680  2004-12-31         Jeopardy!
# 6             4680  2004-12-31         Jeopardy!
# 7             4680  2004-12-31         Jeopardy!
# 8             4680  2004-12-31         Jeopardy!
# 9             4680  2004-12-31         Jeopardy!
# 10            4680  2004-12-31         Jeopardy!
# 11            4680  2004-12-31         Jeopardy!
# 12            4680  2004-12-31         Jeopardy!
# 13            4680  2004-12-31         Jeopardy!
# 14            4680  2004-12-31         Jeopardy!
# 15            4680  2004-12-31         Jeopardy!
# 16            4680  2004-12-31         Jeopardy!
# 17            4680  2004-12-31         Jeopardy!
# ...

# %%
jeopardy.columns
# Out:
# Index(['Show Number', ' Air Date', ' Round', ' Category', ' Value',
#        ' Question', ' Answer'],
#       dtype='object')

# %%
jeopardy.columns = ['Show Number', 'Air Date', 'Round', 'Category', 'Value', 'Question', 'Answer']

# %%
import re

def normalize_text(string):
    string = string.lower()
    string = re.sub("[^A-Za-z0-9\s]", "", string)
    string = re.sub("\s+", " ", string)
    return string

def normalize_values(string):
    string = re.sub("[^A-Za-z0-9\s]", "", string)
    try:
        string = int(string)
    except Exception:
        string = 0
    return string

# %%
jeopardy["clean_question"] = jeopardy["Question"].apply(normalize_text)
jeopardy["clean_answer"] = jeopardy["Answer"].apply(normalize_text)
jeopardy["clean_value"] = jeopardy["Value"].apply(normalize_values)

# %%
jeopardy.head()
# Out:
#    Show Number    Air Date      Round                         Category Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY  $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer  \
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams
#
#                                       clean_question clean_answer  clean_value
# ...

# %%
# remove dollar sign and make value column an integer
def normalize_dollar(s):
    s = s.replace('$','').replace(',','')
    if s=='None':
        s=0.0
    else:
        s=int(s)
    return s

jeopardy['clean_value'] = jeopardy['Value'].apply(lambda x:normalize_dollar(x))

# %%
jeopardy['Air Date'] = pd.to_datetime(jeopardy['Air Date'])

# %%
def count_matches(row):
    split_answer = row['clean_answer'].split()
    split_question = row['clean_question'].split()
    if "the" in split_answer:
        split_answer.remove("the")
    if len(split_answer) == 0:
        return 0
    match_count = 0
    for i in split_answer:
        if i in split_question:
            match_count += 1
    return match_count / len(split_answer)

jeopardy['answer_in_question'] = jeopardy.apply(count_matches, axis=1)

# %%
jeopardy['answer_in_question'].mean()
# Out:
# 0.05900196524977763

# %% [markdown]
# The mean shows that recycled questions occur slightly less than 6% of the time, so there is not likely much benefit to spending time studying old questions.

# %%
question_overlap = []
terms_used = set()

jeopardy = jeopardy.sort_values('Air Date')

for i, row in jeopardy.iterrows():
    split_question = row['clean_question'].split()
    split_question = [q for q in split_question if len(q) > 5]
    match_count = 0
    for word in split_question:
        if word in terms_used:
            match_count += 1
    for word in split_question:
        terms_used.add(word)
    if len(split_question) > 0:
        match_count /= len(split_question)
    question_overlap.append(match_count)
jeopardy["question_overlap"] = question_overlap

jeopardy["question_overlap"].mean()
# Out:
# 0.6877234805400583

# %% [markdown]
# We see that terms do often reoccur, approximately 70% of the time. This is worth considering, however there are a lot of terms. Let's narrow this terms list down to ones that only reoccur between high value questions so we get more value out of each terms we study.

# %%
def clean_value(val):
    value = 0
    if val['clean_value'] > 800:
        value = 1
    return value

jeopardy["high_value"] = jeopardy.apply(clean_value, axis=1)

# %%
def count_usage(term):
    low_count = 0
    high_count = 0
    for i, row in jeopardy.iterrows():
        if term in row["clean_question"].split(" "):
            if row["high_value"] == 1:
                high_count += 1
            else:
                low_count += 1
    return high_count, low_count

# %%
from random import choice

terms_used_list = list(terms_used)
comparison_terms = [choice(terms_used_list) for _ in range(10)]

observed_expected = []

for term in comparison_terms:
    observed_expected.append(count_usage(term))

observed_expected
# Out:
# [(0, 1),
#  (4, 10),
#  (1, 0),
#  (1, 0),
#  (0, 1),
#  (1, 0),
#  (1, 5),
#  (9, 23),
#  (0, 2),
#  (1, 0)]

# %%
from scipy.stats import chisquare
import numpy as np

high_value_count = jeopardy[jeopardy["high_value"] == 1].shape[0]
low_value_count = jeopardy[jeopardy["high_value"] == 0].shape[0]

chi_squared = []
for obs in observed_expected:
    total = sum(obs)
    total_prop = total / jeopardy.shape[0]
    high_value_exp = total_prop * high_value_count
    low_value_exp = total_prop * low_value_count
    
    observed = np.array([obs[0], obs[1]])
    expected = np.array([high_value_exp, low_value_exp])
    chi_squared.append(chisquare(observed, expected))

chi_squared
# Out:
# [Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=6.846341565692304e-05, pvalue=0.993398169235444),
#  Power_divergenceResult(statistic=2.487792117195675, pvalue=0.11473257634454047),
#  Power_divergenceResult(statistic=2.487792117195675, pvalue=0.11473257634454047),
#  Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=2.487792117195675, pvalue=0.11473257634454047),
#  Power_divergenceResult(statistic=0.42281054506129573, pvalue=0.515537958129453),
#  Power_divergenceResult(statistic=0.0046720966866029695, pvalue=0.9455048440167843),
#  Power_divergenceResult(statistic=0.803925692253768, pvalue=0.3699222378079571),
#  Power_divergenceResult(statistic=2.487792117195675, pvalue=0.11473257634454047)]

# %% [markdown]
# # Chi_Squared Results
#
# There was no significant difference in the usage between high value and low value rows. We are unable to show that high or low value terms are more likely to reoccur in jeopardy questions.

# %%
jeopardy.head()
# Out:
#        Show Number   Air Date            Round               Category Value  \
# 19325           10 1984-09-21  Final Jeopardy!        U.S. PRESIDENTS  None
# 19274           10 1984-09-21        Jeopardy!              GEOGRAPHY  $100
# 19275           10 1984-09-21        Jeopardy!            DOUBLE TALK  $100
# 19276           10 1984-09-21        Jeopardy!  "JACKS" OF ALL TRADES  $100
# 19277           10 1984-09-21        Jeopardy!                  SHIPS  $100
#
#                                                 Question              Answer  \
# 19325  Adventurous 26th president, he was 1st to ride...  Theodore Roosevelt
# 19274                                   Formerly Formosa              Taiwan
# 19275  Not a Hawaiian cow, but a dress worn by Hawaii...            a muumuu
# 19276           He celebrated his 39th birthday 41 times          Jack Benny
# 19277  "Unsinkable" for most of its maiden voyage in ...         the Titanic
#
# ...

# %% [markdown]
# It may be that ther is a lack of differences found because there are so many random terms being evaluated. Let's look at the category section to see the frequency of different categories occuring.

# %%
cat_count = jeopardy['Category'].value_counts()

# %%
print(cat_count.to_dict())
# Out:
# {'NAME THE FILM': 5, '"P.D." QUEUE': 5, '"PER"CUSSION': 5, 'BIBLICAL PAIRS': 5, 'ROBERT LOUIS STEVENSON': 5, 'MAGAZINE FEATURES': 5, 'I PLAY THE DRUMS!': 5, 'WAY BACK IN THE 1990s': 5, 'AT THE BUILDING SITE': 5, '"P.S."': 5, 'POP MUSIC': 20, "HORS D'OEUVRES": 5, 'NYC MUSIC HISTORY': 5, 'HOW NOVEL': 5, 'FINISH THE PALINDROME': 5, 'CHERCHEZ LA FEMME': 5, 'FOR WHOM THE "BELL" TOLLS': 5, 'MR. NOODLE': 5, 'THE SONG DYNASTY': 10, 'AROUND THE APARTMENT BUILDING': 5, "WAS HIS NAME O'": 5, 'A LITERARY TOUR': 5, 'THE QUOTABLE BEN FRANKLIN': 5, 'MY NAME IS EARL WARREN': 5, 'SHOP TALK': 5, 'TOP OF THE LIST': 5, 'ART & ARTISTS': 25, 'ANIMALS IN JEOPARDY': 5, "NOW YOU'RE TALKING MY LANGUAGE": 5, 'LITERARY SISTERS': 5, 'DEMOCRATIC KEYNOTERS': 5, "I THINK WE'RE ALONE NOW": 5, 'ELEMENT"S"': 5, '"N"VELOPED': 5, 'RANKS & TITLES': 12, 'CIVIL WAR LITERATURE': 5, 'MOVIE SONGS': 10, 'EXPRESSIONS': 3, 'SIGNS OF THE TIMES': 5, "POETS' RHYME TIME": 10, 'MY DORM ROOM IS SO SMALL...': 5, 'THE EYES HAVE IT': 5, 
# ...

# %%
cat_count.sort_values(ascending=False)[:20]
# Out:
# TELEVISION          51
# U.S. GEOGRAPHY      50
# LITERATURE          45
# AMERICAN HISTORY    40
# HISTORY             40
# BEFORE & AFTER      40
# AUTHORS             39
# WORD ORIGINS        38
# WORLD CAPITALS      37
# SPORTS              36
# BODIES OF WATER     36
# RHYME TIME          35
# MAGAZINES           35
# SCIENCE & NATURE    35
# SCIENCE             35
# WORLD GEOGRAPHY     33
# ANNUAL EVENTS       32
# WORLD HISTORY       32
# HISTORIC NAMES      32
# BIRDS               31
# Name: Category, dtype: int64

# %% [markdown]
# Here we have a frequency list of the top 20 reoccuring categories, it would be a good idea to give attention to each topic accordingly.
